# %% [markdown]
# ![0_awbekd-RK9TrISOn.webp](attachment:0_awbekd-RK9TrISOn.webp)

# %% [markdown]
# ![68747470733a2f2f6d69726f2e6d656469756d2e636f6d2f6d61782f3630362f312a497462492d4c774f4854484c6752744b55594b5f5a672e706e67.png](attachment:68747470733a2f2f6d69726f2e6d656469756d2e636f6d2f6d61782f3630362f312a497462492d4c774f4854484c6752744b55594b5f5a672e706e67.png)

# %% [markdown]
# # Import Libraries

# %%
#type your code here

# %% [markdown]
# # Loading data in pandas

# %%
#type your code here

# %% [markdown]
# # EDA
# * .head()
# * .tail()
# * .info()
# * .describe()

# %%
#type your code here

# %% [markdown]
# # Check the max and min Age based on the Sex "male / female" hint.. use groupby()

# %%
#type your code here

# %% [markdown]
# # Dropping Columns which are not usefull
#
# Lets try to drop some of the columns which many not contribute much to our machine learning model such as Name, Ticket, Cabin

# %%
#type your code here

# %% [markdown]
# # Check the Missing Values

# %%
#type your code here

# %% [markdown]
# # How to handle the Missing Values

# %%
#type your code here

# %% [markdown]
# # Check the Duplicated Rows

# %%
#type your code here

# %% [markdown]
# # How to handle the duplicated rows

# %%
#type your code here

# %% [markdown]
# # Visualize the count of each value in Sex col

# %%
#type your code here

# %% [markdown]
# # Replace 0 with No and 1 with Yes in Survived col

# %%
#type your code here

# %% [markdown]
# # Visualize the count of each value in Survived col

# %%
#type your code here

# %% [markdown]
# # Visualize the distribution of the Age col

# %%
#type your code here

# %% [markdown]
# # Creating Dummy Variables
# 'Pclass', 'Sex', 'Embarked'

# %%
#type your code here

# %% [markdown]
# # Conclusion

# %%
# Type Here
